# %%
import numpy as np
from gensim.models import KeyedVectors

# %%
# load the word embedding model
wv = KeyedVectors.load_word2vec_format('bio_embedding_intrinsic', binary=True)
# and our approved drug names
drugs = None
with open('fda_approved/fda_approved.processed.names') as infile:
    drugs = [l.strip() for l in infile]

# %%
# we're first going to convert every multi-token drug into a word vector average
def wv_avg_tokens(tokens, wv):
    # collect the unit vectors for each token
    unit_vecs = list()
    for t in tokens:
        # skip tokens that aren't in the embedding
        if t in wv:
            # scale to a unit vector
            uvec = wv[t]
            uvec = uvec / np.linalg.norm(uvec)
            unit_vecs.append(uvec)
    # now add them up if we got at least one
    if len(unit_vecs) < 1:
        return None
    # sum
    ret_vec = unit_vecs[0]
    for uvec in unit_vecs[1:]:
        ret_vec = ret_vec + uvec
    # and rescale
    ret_vec = ret_vec / np.linalg.norm(ret_vec)
    return ret_vec

# %%
# do the conversion and make note of any that don't come out with a vector
drug_vectors = list()
for d in drugs:
    toks = d.split()
    dvec = wv_avg_tokens(toks, wv)
    if dvec is None:
        print('No vector for: {0}'.format(d))
    else:
        drug_vectors.append((d, dvec))
# Out:
# No vector for: a-hydrocort
# No vector for: a-methapred
# No vector for: a-poxide
# No vector for: a.p.l.
# No vector for: a/t/s
# No vector for: abitrexate
# No vector for: ablysinol
# No vector for: abrilada
# No vector for: absorica
# No vector for: acanya
# No vector for: accretropin
# No vector for: accrufer
# No vector for: accuneb
# No vector for: accurbron
# No vector for: accuretic
# No vector for: aceon
# No vector for: acetasol
# No vector for: aches-n-pain
# No vector for: acilac
# No vector for: aclovate
# No vector for: acrisorcin
# No vector for: actahist
# No vector for: acticlate
# No vector for: acticort
# No vector for: actidil
# No vector for: actin-n
# No vector for: actinex
# No vector for: activella
# No vector for: adagen
# No vector for: adakveo
# No vector for: adalimumab-adaz
# No vector for: adalimumab-adbm
# No vector for: adalimumab-afzb
# No vector for: adalimumab-atto
# No vector for: adalimumab-bwwd
# No vector for: adipex-p
# No vector for: adlyxin
# No vector for: admelog
# No vector for: adphen
# No vector for: adrenaclick
# No vector for: aemcolo
# No vector for: aerolone
# No vector for: aeroseb-dex
# No vector for: aeroseb-hc
# No vector for: afaxin
# No vector for: afirmelle
# No vector for: afrinol
# No vector for: aimovig
# No vector for: airduo digihaler
# No vector for: airduo respiclick
# No vector for: ajovy
# No vector for: ak-fluor 10%
# No vector for: ak-fluor 25%
# No vector for: ak-pentolate
# No vector for: aklief
# No vector for: akne-mycin
# No vector for: akovaz
# No vector for: akpentolate
# No vector for: akpro
# No vector for: akrinol
# No vector for: aktipak
# No vector for: aktob
# No vector for: ala-cort
# No vector for: ala-scalp
# No vector for: alamast
# No vector for: alavert
# No vector for: alaway
# No vector for: albalon
# No vector for: albenza
# No vector for: aldoclor-150
# No vector for: aldoclor-250
# No vector for: alfenta
# No vector for: aliqopa
# No vector for: alkavervir
# No vector for: alkergot
# No vector for: allerfed
# No vector for: allernaze
# No vector for: allzital
# No vector for: alocril
# No vector for: aloprim
# No vector for: alphacaine
# No vector for: alphadrol
# No vector for: alphalin
# No vector for: alpharedisol
# No vector for: alphatrex
# No vector for: alphazine
# No vector for: alsuma
# No vector for: altace
# No vector for: altafluor benox
# No vector for: altavera
# No vector for: altoprev
# No vector for: altreno
# No vector for: alunbrig
# No vector for: alyacen 1/35
# No vector for: alyacen 7/7/7
# No vector for: alyq
# No vector for: amabelz
# No vector for: ambenyl
# No vector for: amcill
# No vector for: amerge
# No vector for: aminosyn-hbc 7%
# No vector for: aminosyn-hf 8%
# No vector for: aminosyn-rf 5.2%
# No vector for: amitid
# No vector for: amitril
# No vector for: amjevita
# No vector for: ammonul
# No vector for: amnesteem
# No vector for: amnestrogen
# No vector for: amosene
# No vector for: amphadase
# No vector for: amrix
# No vector for: amturnide
# No vector for: amvaz
# No vector for: amzeeq
# No vector for: an-dtpa
# No vector for: ancobon
# No vector for: android-f
# No vector for: anestacon
# No vector for: anexsia
# No vector for: anexsia 5/325
# No vector for: anexsia 7.5/325
# No vector for: anexsia 7.5/650
# No vector for: anhydron
# No vector for: anjeso
# No vector for: annovera
# No vector for: anoquan
# No vector for: anspor
# No vector for: antagonate
# No vector for: anthim
# No vector for: apadaz
# No vector for: aphthasol
# No vector for: aplenzin
# No vector for: apogen
# No vector for: apokyn
# No vector for: apresazide
# No vector for: apresoline-esidrix
# No vector for: aquamephyton
# No vector for: aquaphyllin
# No vector for: aquatag
# No vector for: aquatensen
# No vector for: arakoda
# No vector for: aranelle
# No vector for: arazlo
# No vector for: aristogel
# No vector for: aristospan
# No vector for: armonair respiclick
# No vector for: asbron
# No vector for: asclera
# No vector for: ashlyna
# No vector for: asparlas
# No vector for: astepro
# No vector for: atelvia
# No vector for: athrombin
# No vector for: athrombin-k
# No vector for: atnaa
# No vector for: atralin
# No vector for: aurovela 1.5/30
# No vector for: aurovela 1/20
# No vector for: auryxia
# No vector for: austedo
# No vector for: avaclyr
# No vector for: avandaryl
# No vector for: avapritinib
# No vector for: aveed
# No vector for: aventyl
# No vector for: aviane-21
# No vector for: aviane-28
# No vector for: avsola
# No vector for: axotal
# No vector for: axumin
# No vector for: aygestin
# No vector for: ayuna
# No vector for: ayvakit
# No vector for: azasan
# No vector for: azdone
# No vector for: azedra
# No vector for: azelex
# No vector for: azlin
# No vector for: azolid
# No vector for: baci-rx
# No vector for: baciguent
# No vector for: baciim
# No vector for: bacitracin-neomycin-polymyxin
# No vector for: bactocill
# No vector for: balcoltra
# No vector for: balneol-hc
# No vector for: baloxavir marboxil
# No vector for: balversa
# No vector for: balziva-21
# No vector for: balziva-28
# No vector for: bamate
# No vector for: bancap
# No vector for: banzel
# No vector for: baqsimi
# No vector for: barhemsys
# No vector for: bavencio
# No vector for: baxdela
# No vector for: beepen-vk
# No vector for: bekyree
# No vector for: belbuca
# No vector for: beldin
# No vector for: belix
# No vector for: belrapzo
# No vector for: bendeka
# No vector for: bendopa
# No vector for: benoquin
# No vector for: bensulfoid
# No vector for: bentoquatam
# No vector for: beovu
# No vector for: bepadin
# No vector for: bepreve
# No vector for: berubigen
# No vector for: besponsa
# No vector for: beta-val
# No vector for: betaderm
# No vector for: betapar
# No vector for: betapen-vk
# No vector for: betatrex
# No vector for: betaxon
# No vector for: bethkis
# No vector for: bevacizumab-awwb
# No vector for: bevacizumab-bvzr
# No vector for: bevyxxa
# No vector for: bijuva
# No vector for: biktarvy
# No vector for: bilivist
# No vector for: binosto
# No vector for: bio-tropin
# No vector for: biorphen
# No vector for: bioscrub
# No vector for: biphetamine 12.5
# No vector for: biphetamine 7.5
# No vector for: bleph-10
# No vector for: bleph-30
# No vector for: blephamide
# No vector for: blephamide s.o.p.
# No vector for: bloxiverz
# No vector for: bonjesta
# No vector for: bonsity
# No vector for: bontril
# No vector for: borofair
# No vector for: braftovi
# No vector for: branchamin 4%
# No vector for: brethine
# No vector for: bretylol
# No vector for: briellyn
# No vector for: brineura
# No vector for: bristacycline
# No vector for: bristagen
# No vector for: bristamycin
# No vector for: brixadi
# No vector for: brolucizumab-dbll
# No vector for: bromanyl
# No vector for: bromday
# No vector for: bromfed-dm
# No vector for: brompheril
# No vector for: bromsite
# No vector for: bronkodyl
# No vector for: brovana
# No vector for: brukinsa
# No vector for: bryhali
# No vector for: bryrel
# No vector for: bucet
# No vector for: bucladin-s
# No vector for: bunavail
# No vector for: buprenex
# No vector for: burosumab-twza
# No vector for: butabarb
# No vector for: butalan
# No vector for: butapap
# No vector for: buticaps
# No vector for: byvalson
# No vector for: c-solve-2
# No vector for: cablivi
# No vector for: cafcit
# No vector for: calaspargase pegol-mknl
# No vector for: calcibind
# No vector for: calderol
# No vector for: caldolor
# No vector for: calomist
# No vector for: calquence
# No vector for: cam-ap-es
# No vector for: cam-metrazine
# No vector for: canasa
# No vector for: candex
# No vector for: cap-profen
# No vector for: capitrol
# No vector for: caplacizumab-yhdp
# No vector for: caplyta
# No vector for: carbastat
# No vector for: carbilev
# No vector for: cardiografin
# No vector for: cardioquin
# No vector for: carnexiv
# No vector for: carospir
# No vector for: cartrol
# No vector for: cassipa
# No vector for: catapres-tts-1
# No vector for: catapres-tts-2
# No vector for: catapres-tts-3
# No vector for: cefadyl
# No vector for: cefmax
# No vector for: cefotan
# No vector for: cemiplimab-rwlc
# No vector for: cenegermin-bkbj
# No vector for: cenobamate
# No vector for: centany
# No vector for: centrax
# No vector for: cephulac
# No vector for: ceptaz
# No vector for: cequa
# No vector for: ceradon
# No vector for: cerdelga
# No vector for: cerinta
# No vector for: cetacort
# No vector for: cetamide
# No vector for: cetapred
# No vector for: cetraxal
# No vector for: cetylev
# No vector for: chenix
# No vector for: chibroxin
# No vector for: children's advil-flavored
# No vector for: children's elixsure
# No vector for: chirhostim
# No vector for: chlordiazachel
# No vector for: chlorofair
# No vector for: chloromyxin
# No vector for: chloroptic
# No vector for: chloroptic s.o.p.
# No vector for: chloroptic-p s.o.p.
# No vector for: chlorothiazide-reserpine
# No vector for: cholac
# No vector for: cholbam
# No vector for: cholybar
# No vector for: chromalbin
# No vector for: chronulac
# No vector for: chymex
# No vector for: cida-stat
# No vector for: cimduo
# No vector for: cin-quin
# No vector for: cinnasil
# No vector for: cinvanti
# No vector for: circanol
# No vector for: cis-mdp
# No vector for: cis-pyro
# No vector for: claravis
# No vector for: clenpiq
# No vector for: clenz-lyte
# No vector for: clinda-derm
# No vector for: clindagel
# No vector for: clindets
# No vector for: clinolipid 20%
# No vector for: clistin
# No vector for: cloderm
# No vector for: clolar
# No vector for: clopra
# No vector for: clopra-""yellow""
# No vector for: clorotekal
# No vector for: clorpres
# No vector for: clovique
# No vector for: cloxapen
# No vector for: co-gesic
# No vector for: co-lav
# No vector for: coactin
# No vector for: cobavite
# No vector for: codeprex
# No vector for: codoxy
# No vector for: codrix
# No vector for: col-probenecid
# No vector for: colbenemid
# No vector for: colocort
# No vector for: colonaid
# No vector for: colovage
# No vector for: colyte-flavored
# No vector for: combipres
# No vector for: combunox
# No vector for: compro
# No vector for: concentraid
# No vector for: condylox
# No vector for: conjupri
# No vector for: constilac
# No vector for: constulose
# No vector for: conzip
# No vector for: copiktra
# No vector for: cor-oticin
# No vector for: corlopam
# No vector for: cormax
# No vector for: corphed
# No vector for: corphedra
# No vector for: corsym
# No vector for: cort-dome
# No vector for: cortalone
# No vector for: cortan
# No vector for: cortifoam
# No vector for: cortrophin-zinc
# No vector for: corvert
# No vector for: corzide
# No vector for: cotellic
# No vector for: covera-hs
# No vector for: crizanlizumab-tmca
# No vector for: crolom
# No vector for: cromoptic
# No vector for: crotan
# No vector for: cryselle
# No vector for: crystodigin
# No vector for: crysvita
# No vector for: curretab
# No vector for: cuvposa
# No vector for: cyclafem 0.5/35
# No vector for: cyclafem 1/35
# No vector for: cyclafem 7/7/7
# No vector for: cyclapen-w
# No vector for: cyclocort
# No vector for: cyclopar
# No vector for: cycrin
# No vector for: cyltezo
# No vector for: cyonanz
# No vector for: cystadane
# No vector for: cystaran
# No vector for: cytadren
# No vector for: dalgan
# No vector for: daliresp
# No vector for: darbid
# No vector for: dasetta 1/35
# No vector for: dasetta 7/7/7
# No vector for: daurismo
# No vector for: daysee
# No vector for: dayvigo
# No vector for: deapril-st
# No vector for: decabid
# No vector for: decaderm
# No vector for: decadron-la
# No vector for: decaspray
# No vector for: del-vi-a
# No vector for: delatestryl
# No vector for: delaxin
# No vector for: delcobese
# No vector for: delstrigo
# No vector for: delsym
# No vector for: delta-cortef
# No vector for: delta-dome
# No vector for: deltalin
# No vector for: deltasone
# No vector for: delzicol
# No vector for: demadex
# No vector for: demi-regroton
# No vector for: demser
# No vector for: dendrid
# No vector for: depen
# No vector for: depinar
# No vector for: depo-testadiol
# No vector for: derma-smoothe/fs
# No vector for: dermabet
# No vector for: dermacort
# No vector for: dermotic
# No vector for: descovy
# No vector for: desonate
# No vector for: desowen
# No vector for: dexacen-4
# No vector for: dexacidin
# No vector for: dexair
# No vector for: dexampex
# No vector for: dexasporin
# No vector for: dexilant
# No vector for: dextrostat
# No vector for: di-atro
# No vector for: di-metrex
# No vector for: diapid
# No vector for: diatrizoate-60
# No vector for: dibenil
# No vector for: dilantin-125
# No vector for: dilantin-30
# No vector for: dilatrate-sr
# No vector for: dilaudid-hp
# No vector for: dilor-400
# No vector for: dilt-cd
# No vector for: diltzac
# No vector for: dimetane-dx
# No vector for: dimetane-ten
# No vector for: disobrom
# No vector for: disomer
# No vector for: dispermox
# No vector for: ditate-ds
# No vector for: diucardin
# No vector for: diulo
# No vector for: diupres-250
# No vector for: diupres-500
# No vector for: diutensen-r
# No vector for: dizac
# No vector for: docefrez
# No vector for: dodex
# No vector for: dofetilde
# No vector for: dolene
# No vector for: dolene ap-65
# No vector for: dopar
# No vector for: doptelet
# No vector for: dormate
# No vector for: dovato
# No vector for: dow-isoniazid
# No vector for: doxy-lemmon
# No vector for: doxy-sleep-aid
# No vector for: doxychel
# No vector for: dralserp
# No vector for: dralzine
# No vector for: dricort
# No vector for: drisdol
# No vector for: drixoral
# No vector for: drolban
# No vector for: droxia
# No vector for: dsuvia
# No vector for: duetact
# No vector for: dulera
# No vector for: duo-medihaler
# No vector for: duobrii
# No vector for: duocaine
# No vector for: duodote
# No vector for: duoneb
# No vector for: dupixent
# No vector for: duracillin a.s.
# No vector for: duraclon
# No vector for: duragesic-100
# No vector for: duragesic-12
# No vector for: duragesic-25
# No vector for: duragesic-37
# No vector for: duragesic-50
# No vector for: duragesic-75
# No vector for: duraphyl
# No vector for: duraquin
# No vector for: durlaza
# No vector for: durysta
# No vector for: dutoprol
# No vector for: dutrebis
# No vector for: duvoid
# No vector for: duzallo
# No vector for: dycill
# No vector for: dyclopro
# No vector for: dynabac
# No vector for: dynacin
# No vector for: dynapen
# No vector for: e-base
# No vector for: e-glades
# No vector for: e.e.s.
# No vector for: ec-naprosyn
# No vector for: econochlor
# No vector for: ecoza
# No vector for: edarbyclor
# No vector for: egaten
# No vector for: egrifta
# No vector for: elapegademase-lvlr
# No vector for: elase-chloromycetin
# No vector for: elcys
# No vector for: eldecort
# No vector for: elestat
# No vector for: elestrin
# No vector for: elifemme
# No vector for: elinest
# No vector for: eliphos
# No vector for: elixicon
# No vector for: elixomin
# No vector for: eluryng
# No vector for: elzonris
# No vector for: emapalumab-lzsg
# No vector for: emete-con
# No vector for: emflaza
# No vector for: emgality
# No vector for: emgel
# No vector for: emoquette
# No vector for: emverm
# No vector for: enablex
# No vector for: endari
# No vector for: enduronyl
# No vector for: enhertu
# No vector for: enjuvia
# No vector for: enlon
# No vector for: enlon-plus
# No vector for: enpresse-21
# No vector for: enpresse-28
# No vector for: enskyce
# No vector for: enstilar
# No vector for: enulose
# No vector for: epaned
# No vector for: epicort
# No vector for: epogen/procrit
# No vector for: eptinezumab-jjmr
# No vector for: equagesic
# No vector for: equipin
# No vector for: erelzi
# No vector for: erenumab-aooe
# No vector for: ergomar
# No vector for: ergostat
# No vector for: erleada
# No vector for: errin
# No vector for: ertaczo
# No vector for: ery-tab
# No vector for: erycette
# No vector for: eryderm
# No vector for: erygel
# No vector for: erymax
# No vector for: erypar
# No vector for: eryped
# No vector for: erythra-derm
# No vector for: erythro-statin
# No vector for: eryzole
# No vector for: esgic
# No vector for: esgic-plus
# No vector for: esimil
# No vector for: eskata
# No vector for: estarylla
# No vector for: estraguard
# No vector for: etanercept-szzs
# No vector for: etanercept-ykro
# No vector for: ethamolin
# No vector for: eticovo
# No vector for: etrafon-a
# No vector for: etrafon-forte
# No vector for: eucrisa
# No vector for: euthroid-0.5
# No vector for: euthroid-1
# No vector for: euthroid-2
# No vector for: euthroid-3
# No vector for: eutron
# No vector for: evalose
# No vector for: evamist
# No vector for: evekeo
# No vector for: evenity
# No vector for: evoclin
# No vector for: evotaz
# No vector for: exalgo
# No vector for: exelderm
# No vector for: exidine
# No vector for: exservan
# No vector for: ezallor
# No vector for: fabior
# No vector for: falmina
# No vector for: fam-trastuzumab deruxtecan-nxki
# No vector for: fasenra
# No vector for: fayosim
# No vector for: femcet
# No vector for: feminone
# No vector for: femogen
# No vector for: fempatch
# No vector for: femring
# No vector for: femstat
# No vector for: femtrace
# No vector for: fenoglide
# No vector for: fentanyl-100
# No vector for: fentanyl-12
# No vector for: fentanyl-25
# No vector for: fentanyl-37
# No vector for: fentanyl-50
# No vector for: fentanyl-62
# No vector for: fentanyl-75
# No vector for: fentanyl-87
# No vector for: ferndex
# No vector for: fernisolone-p
# No vector for: fernisone
# No vector for: fetroja
# No vector for: fiasp
# No vector for: fibricor
# No vector for: filgrastim-aafi
# No vector for: flarex
# No vector for: flexicort
# No vector for: flo-pred
# No vector for: flolipid
# No vector for: floropryl
# No vector for: flowtuss
# No vector for: fluidil
# No vector for: flumadine
# No vector for: fluocet
# No vector for: fluonid
# No vector for: fluor-op
# No vector for: fluorescite
# No vector for: fluoroplex
# No vector for: fluotrex
# No vector for: flutex
# No vector for: fluxid
# No vector for: fml-s
# No vector for: foamcoat
# No vector for: foamicon
# No vector for: folex
# No vector for: folicet
# No vector for: folvite
# No vector for: folvron
# No vector for: forbaxin
# No vector for: fortamet
# No vector for: fortaz
# No vector for: fortical
# No vector for: fovane
# No vector for: fremanezumab-vfrm
# No vector for: fulphila
# No vector for: fulvicin-u/f
# No vector for: funduscein-25
# No vector for: furalan
# No vector for: fusilev
# No vector for: fyavolv
# No vector for: gablofen
# No vector for: galafold
# No vector for: galcanezumab-gnlm
# No vector for: galzin
# No vector for: gamene
# No vector for: gamifant
# No vector for: gamophen
# No vector for: ganite
# No vector for: gantanol-ds
# No vector for: ganzyk-rtu
# No vector for: gastrocrom
# No vector for: gastromark
# No vector for: gastrovist
# No vector for: gemonil
# No vector for: gen-xene
# No vector for: genapax
# No vector for: gencept 10/11-21
# No vector for: gencept 10/11-28
# No vector for: generlac
# No vector for: genesa
# No vector for: genoptic
# No vector for: genosyl
# No vector for: gentafair
# No vector for: gentak
# No vector for: geocillin
# No vector for: geopen
# No vector for: gerimal
# No vector for: germa-medica
# No vector for: germa-medica ""mg""
# No vector for: giapreza
# No vector for: giazo
# No vector for: gildagia
# No vector for: gildess 1.5/30
# No vector for: gildess 1/20
# No vector for: givlaari
# No vector for: gleolan
# No vector for: gleostine
# No vector for: glofil-125
# No vector for: gloperba
# No vector for: glycolax
# No vector for: glycoprep
# No vector for: glycort
# No vector for: glydo
# No vector for: glyrx-pf
# No vector for: glyset
# No vector for: go-evac
# No vector for: gocovri
# No vector for: golodirsen
# No vector for: gonitro
# No vector for: goprelto
# No vector for: granisol
# No vector for: grisactin
# No vector for: griseofulvin, ultramicrocrystalline
# No vector for: griseofulvin,ultramicrosize
# No vector for: gvoke hypopen
# No vector for: gynazole-1
# No vector for: gyne-lotrimin
# No vector for: gyne-sulf
# No vector for: gynix
# No vector for: gynodiol
# No vector for: gynorest
# No vector for: h.r.-50
# No vector for: hadlima
# No vector for: haldrone
# No vector for: halog-e
# No vector for: halotex
# No vector for: harmonyl
# No vector for: helicosol
# No vector for: helidac
# No vector for: hemady
# No vector for: hemlibra
# No vector for: hemsol-hc
# No vector for: hepatasol 8%
# No vector for: hepatolite
# No vector for: heptalac
# No vector for: herplex
# No vector for: herzuma
# No vector for: hexa-betalin
# No vector for: hexa-germ
# No vector for: hexascrub
# No vector for: hi-cor
# No vector for: hibistat
# No vector for: hipputope
# No vector for: hiserpia
# No vector for: hispril
# No vector for: histafed
# No vector for: hiwolfia
# No vector for: homapin-10
# No vector for: homapin-5
# No vector for: humorsol
# No vector for: hy-pam ""25""
# No vector for: hy-phen
# No vector for: hyaluronidase-oysk
# No vector for: hycodan
# No vector for: hycofenix
# No vector for: hydeltra-tba
# No vector for: hydeltrasol
# No vector for: hydra-zide
# No vector for: hydramine
# No vector for: hydrap-es
# No vector for: hydro-d
# No vector for: hydro-reserp
# No vector for: hydro-ride
# No vector for: hydro-rx
# No vector for: hydro-serp ""25""
# No vector for: hydro-serp ""50""
# No vector for: hydromox
# No vector for: hydropane
# No vector for: hydroxomin
# No vector for: hylorel
# No vector for: hypaque-cysto
# No vector for: hypaque-m,75%
# No vector for: hypaque-m,90%
# No vector for: hyprotigen 5%
# No vector for: hyrimoz
# No vector for: hyserpin
# No vector for: hyzyd
# No vector for: ibalizumab-uiyk
# No vector for: ibsrela
# No vector for: ibu-tab
# No vector for: ibuprin
# No vector for: ibuprohm
# No vector for: iclevia
# No vector for: idamycin
# No vector for: idhifa
# No vector for: idkit:hp
# No vector for: ilevro
# No vector for: ilumya
# No vector for: imfinzi
# No vector for: impoyz
# No vector for: imvexxy
# No vector for: inbrija
# No vector for: incassia
# No vector for: inderide-40/25
# No vector for: inderide-80/25
# No vector for: indiclor
# No vector for: indo-lemmon
# No vector for: infants' feverall
# No vector for: infliximab-abda
# No vector for: infliximab-axxq
# No vector for: infliximab-dyyb
# No vector for: infliximab-qbtx
# No vector for: infugem
# No vector for: injectafer
# No vector for: injectapap
# No vector for: innofem
# No vector for: inrebic
# No vector for: intrarosa
# No vector for: introvale
# No vector for: invagesic
# No vector for: inveltys
# No vector for: invokamet
# No vector for: iodotope
# No vector for: ionamin
# No vector for: iontocaine
# No vector for: iopamidol-200
# No vector for: iopamidol-250
# No vector for: iosat
# No vector for: iprivask
# No vector for: iquix
# No vector for: isatuximab-irfc
# No vector for: isibloom
# No vector for: ismotic
# No vector for: isoclor
# No vector for: isovue-128
# No vector for: isovue-200
# No vector for: isovue-250
# No vector for: isovue-300
# No vector for: istalol
# No vector for: isturisa
# No vector for: ivadantin
# No vector for: ivosidenib
# No vector for: ixifi
# No vector for: izba
# No vector for: jadenu
# No vector for: jaimiess
# No vector for: jalyn
# No vector for: janimine
# No vector for: jantoven
# No vector for: jatenzo
# No vector for: jeanatope
# No vector for: jencycla
# No vector for: jenloga
# No vector for: jeuveau
# No vector for: juluca
# No vector for: junel 1.5/30
# No vector for: junel 1/20
# No vector for: juvisync
# No vector for: jynarque
# No vector for: k+10
# No vector for: k+8
# No vector for: k-lease
# No vector for: k-tab
# No vector for: kafocin
# No vector for: kainair
# No vector for: kalexate
# No vector for: kalliga
# No vector for: kanjinti
# No vector for: kantrex
# No vector for: kappadione
# No vector for: kapvay
# No vector for: kariva
# No vector for: katerzia
# No vector for: keflet
# No vector for: keftab
# No vector for: kefurox
# No vector for: kelnor
# No vector for: kemeya
# No vector for: kemstro
# No vector for: kenalog-10
# No vector for: kenalog-80
# No vector for: kenalog-h
# No vector for: kengreal
# No vector for: kerledex
# No vector for: kerydin
# No vector for: kesso-gesic
# No vector for: ketozole
# No vector for: keveyis
# No vector for: kevzara
# No vector for: khapzory
# No vector for: khedezla
# No vector for: kimidess
# No vector for: kinlytic
# No vector for: kionex
# No vector for: kisqali
# No vector for: klaron
# No vector for: klebcil
# No vector for: klor-con
# No vector for: kloromin
# No vector for: klotrix
# No vector for: koglucoid
# No vector for: korlym
# No vector for: korostatin
# No vector for: kovanaze
# No vector for: krintafel
# No vector for: kurvelo
# No vector for: kyra
# No vector for: lanabiotic
# No vector for: laniazid
# No vector for: lanophyllin
# No vector for: lanorinal
# No vector for: lantrisul
# No vector for: largon
# No vector for: larotid
# No vector for: laxilose
# No vector for: lazanda
# No vector for: leribane
# No vector for: leritine
# No vector for: lessina-21
# No vector for: lessina-28
# No vector for: levatol
# No vector for: levlite
# No vector for: levo-t
# No vector for: levolet
# No vector for: levonest
# No vector for: levora 0.15/30-21
# No vector for: levora 0.15/30-28
# No vector for: levoxyl
# No vector for: lexette
# No vector for: lexxel
# No vector for: librelease
# No vector for: libritabs
# No vector for: libtayo
# No vector for: licart
# No vector for: lidex-e
# No vector for: lidocaton
# No vector for: lidopen
# No vector for: liotrix
# No vector for: lipo-hepin
# No vector for: lipofen
# No vector for: liptruzet
# No vector for: liquamar
# No vector for: lithane
# No vector for: lithonate
# No vector for: lithostat
# No vector for: lithotabs
# No vector for: lo-malmorede
# No vector for: lo-trol
# No vector for: lo-zumandimine
# No vector for: lo/ovral
# No vector for: lo/ovral-28
# No vector for: locholest
# No vector for: lodosyn
# No vector for: logen
# No vector for: logilia
# No vector for: lokelma
# No vector for: lomaira
# No vector for: lomanate
# No vector for: lonox
# No vector for: lopressidone
# No vector for: lopurin
# No vector for: lorabid
# No vector for: loraz
# No vector for: lorbrena
# No vector for: lorcet-hd
# No vector for: lorelco
# No vector for: loryna
# No vector for: loseasonique
# No vector for: lotusate
# No vector for: low-ogestrel-21
# No vector for: low-ogestrel-28
# No vector for: low-quel
# No vector for: lucemyra
# No vector for: lufyllin
# No vector for: lumify
# No vector for: lumoxiti
# No vector for: lusduna
# No vector for: luspatercept-aamt
# No vector for: lutathera
# No vector for: luxiq
# No vector for: luzu
# No vector for: lybrel
# No vector for: lygen
# No vector for: lymepak
# No vector for: m-predrol
# No vector for: m.v.c. 9+3
# No vector for: macrilen
# No vector for: macrotec
# No vector for: magnacort
# No vector for: malmorede
# No vector for: marlissa
# No vector for: mavenclad
# No vector for: mavik
# No vector for: mavyret
# No vector for: maxalt-mlt
# No vector for: maxibolin
# No vector for: maxzide-25
# No vector for: mayzent
# No vector for: mazanor
# No vector for: md-50
# No vector for: md-60
# No vector for: md-76r
# No vector for: md-gastroview
# No vector for: mdp-bracco
# No vector for: measurin
# No vector for: meclan
# No vector for: meclodium
# No vector for: medihaler-iso
# No vector for: medipren
# No vector for: megatope
# No vector for: mektovi
# No vector for: melamisa
# No vector for: melfiat
# No vector for: melfiat-105
# No vector for: mellaril-s
# No vector for: membraneblue
# No vector for: menest
# No vector for: menostar
# No vector for: mentax
# No vector for: mentax-tc
# No vector for: mepergan
# No vector for: mepriam
# No vector for: mepro-aspirin
# No vector for: meprospan
# No vector for: mepsevii
# No vector for: mersalyl-theophylline
# No vector for: metaglip
# No vector for: metahydrin
# No vector for: metandren
# No vector for: metatensin #2
# No vector for: metatensin #4
# No vector for: methampex
# No vector for: methylin
# No vector for: meti-derm
# No vector for: metimyd
# No vector for: metreton
# No vector for: metrocream
# No vector for: metrogel-vaginal
# No vector for: metrolotion
# No vector for: metromidol
# No vector for: mexate
# No vector for: mexate-aq
# No vector for: mezlin
# No vector for: micort-hc
# No vector for: micrainin
# No vector for: microderm
# No vector for: microgestin 1.5/30
# No vector for: microgestin 1/20
# No vector for: micronase
# No vector for: microsul
# No vector for: microzide
# No vector for: midamor
# No vector for: midol
# No vector for: migergot
# No vector for: migranal
# No vector for: milophene
# No vector for: milprem-200
# No vector for: milprem-400
# No vector for: minitec
# No vector for: minivelle
# No vector for: minodyl
# No vector for: minolira
# No vector for: miochol-e
# No vector for: miradon
# No vector for: miraluma
# No vector for: mitigare
# No vector for: mitigo
# No vector for: mitozytrex
# No vector for: moban
# No vector for: moctanin
# No vector for: moderil
# No vector for: modrastane
# No vector for: mogamulizumab-kpkc
# No vector for: monistat-derm
# No vector for: mono-linyah
# No vector for: monocid
# No vector for: monodox
# No vector for: monoket
# No vector for: monopril-hct
# No vector for: monurol
# No vector for: motegrity
# No vector for: motofen
# No vector for: movantik
# No vector for: moxatag
# No vector for: moxeza
# No vector for: mucosil-10
# No vector for: mucosil-20
# No vector for: mulpleta
# No vector for: multifuge
# No vector for: mvasi
# No vector for: myalept
# No vector for: mycelex
# No vector for: mycelex-7
# No vector for: mycelex-g
# No vector for: mychel
# No vector for: mychel-s
# No vector for: mycifradin
# No vector for: mycitracin
# No vector for: mycolog-ii
# No vector for: mydayis
# No vector for: mydriafair
# No vector for: myfed
# No vector for: myidyl
# No vector for: mykacet
# No vector for: mykinac
# No vector for: mykrox
# No vector for: myorisan
# No vector for: myotonachol
# No vector for: mytesi
# No vector for: myxredlin
# No vector for: myzilra
# No vector for: nafazair
# No vector for: naftin
# No vector for: nallpen
# No vector for: namzaric
# No vector for: naqua
# No vector for: naquival
# No vector for: nasalcrom
# No vector for: nasalide
# No vector for: nasarel
# No vector for: nascobal
# No vector for: natroba
# No vector for: naturetin-10
# No vector for: naturetin-2.5
# No vector for: naturetin-5
# No vector for: navstel
# No vector for: nayzilam
# No vector for: nebupent
# No vector for: neo-cort-dome
# No vector for: neo-cortef
# No vector for: neo-delta-cortef
# No vector for: neo-fradin
# No vector for: neo-hydeltrasol
# No vector for: neo-medrol
# No vector for: neo-polycin
# No vector for: neo-rx
# No vector for: neo-synalar
# No vector for: neobiotic
# No vector for: neodecadron
# No vector for: neopap
# No vector for: neopasalate
# No vector for: neoscan
# No vector for: neothylline
# No vector for: neotrizine
# No vector for: nephroflow
# No vector for: nerlynx
# No vector for: netspot
# No vector for: neuraceq
# No vector for: neuramate
# No vector for: neutrexin
# No vector for: nexcede
# No vector for: nexletol
# No vector for: nexlizet
# No vector for: niacor
# No vector for: niclocide
# No vector for: nicolar
# No vector for: nilandron
# No vector for: nilstat
# No vector for: niravam
# No vector for: nithiodote
# No vector for: nitrol
# No vector for: nitromist
# No vector for: nitronal
# No vector for: nityr
# No vector for: nivestym
# No vector for: nocdurna
# No vector for: noctiva
# No vector for: nor-qd
# No vector for: norcet
# No vector for: nordette-21
# No vector for: nordette-28
# No vector for: norethin 1/35e-21
# No vector for: norethin 1/35e-28
# No vector for: norethin 1/50m-21
# No vector for: norethin 1/50m-28
# No vector for: noritate
# No vector for: norlutate
# No vector for: normodyne
# No vector for: normozide
# No vector for: northera
# No vector for: nortrel 0.5/35-21
# No vector for: nortrel 0.5/35-28
# No vector for: nortrel 1/35-21
# No vector for: nortrel 1/35-28
# No vector for: nortrel 7/7/7
# No vector for: nouress
# No vector for: nourianz
# No vector for: novafed
# No vector for: novamine 11.4%
# No vector for: novamine 15%
# No vector for: novamine 8.5%
# No vector for: novrad
# No vector for: noxivent
# No vector for: nubeqa
# No vector for: nulytely-flavored
# No vector for: numbrino
# No vector for: nuprin
# No vector for: nuromax
# No vector for: nutracort
# No vector for: nutrestore
# No vector for: nutrilipid 10%
# No vector for: nutrilipid 20%
# No vector for: nuvessa
# No vector for: nuzyra
# No vector for: nylia 1/35
# No vector for: nylia 7/7/7
# No vector for: nymalize
# No vector for: nysert
# No vector for: nystaform
# No vector for: nystex
# No vector for: nystop
# No vector for: obestin-30
# No vector for: obredon
# No vector for: oby-trim
# No vector for: ocaliva
# No vector for: ocuclear
# No vector for: ocumycin
# No vector for: ocusulf-10
# No vector for: ocusulf-30
# No vector for: odefsey
# No vector for: oforta
# No vector for: ogestrel 0.5/50-21
# No vector for: ogestrel 0.5/50-28
# No vector for: ogivri
# No vector for: oleptro
# No vector for: olumiant
# No vector for: omnaris
# No vector for: omnicef
# No vector for: omnipen
# No vector for: omnipen-n
# No vector for: omnipred
# No vector for: omtryg
# No vector for: ona-mast
# No vector for: onexton
# No vector for: onmel
# No vector for: onpattro
# No vector for: ontruzant
# No vector for: opcon
# No vector for: opcon-a
# No vector for: ophthochlor
# No vector for: ophthocort
# No vector for: opill
# No vector for: optimine
# No vector for: optomycin
# No vector for: ora-testryl
# No vector for: orabloc
# No vector for: oralone
# No vector for: oraltag
# No vector for: orasone
# No vector for: oravig
# No vector for: orenitram
# No vector for: oreton
# No vector for: orgatrax
# No vector for: orilissa
# No vector for: orlex
# No vector for: orphengesic
# No vector for: orsythia
# No vector for: ortho-cept
# No vector for: ortho-est
# No vector for: ortikos
# No vector for: orvaten
# No vector for: oseni
# No vector for: osteolite
# No vector for: oticair
# No vector for: otiprio
# No vector for: otobione
# No vector for: otobiotic
# No vector for: otocort
# No vector for: otovel
# No vector for: otrexup
# No vector for: ovcon-35
# No vector for: ovcon-50
# No vector for: ovulen-28
# No vector for: oxaydo
# No vector for: oxbryta
# No vector for: oxervate
# No vector for: oxiglutatione
# No vector for: oxilan-300
# No vector for: oxilan-350
# No vector for: oxistat
# No vector for: oxsoralen-ultra
# No vector for: oxy-kesso-tetra
# No vector for: oxycet
# No vector for: ozempic
# No vector for: ozobax
# No vector for: padcev
# No vector for: palynziq
# No vector for: pamelor
# No vector for: pandel
# No vector for: panheprin
# No vector for: panixine disperdose
# No vector for: panmycin
# No vector for: papa-deine #3
# No vector for: papa-deine #4
# No vector for: paracaine
# No vector for: paracort
# No vector for: parasal
# No vector for: parathar
# No vector for: parcopa
# No vector for: paskalium
# No vector for: pathilon
# No vector for: pathocil
# No vector for: paxipam
# No vector for: pazeo
# No vector for: pbz-sr
# No vector for: pediamycin
# No vector for: pediapred
# No vector for: pediotic
# No vector for: peg-lyte
# No vector for: pegfilgrastim-bmez
# No vector for: pegfilgrastim-cbqv
# No vector for: pegfilgrastim-jmdb
# No vector for: pegvaliase-pqpz
# No vector for: pemfexy
# No vector for: penapar-vk
# No vector for: penbritin-s
# No vector for: penecort
# No vector for: penetrex
# No vector for: penicillin-2
# No vector for: penicillin-vk
# No vector for: penntuss
# No vector for: pentacef
# No vector for: pentam
# No vector for: pentids '200'
# No vector for: pentids '250'
# No vector for: pentids '400'
# No vector for: pentids '800'
# No vector for: pentolair
# No vector for: pentoxil
# No vector for: perchloracap
# No vector for: percodan-demi
# No vector for: permapen
# No vector for: permitil
# No vector for: pertzye
# No vector for: pexeva
# No vector for: pfizer-e
# No vector for: pfizerpen
# No vector for: pfizerpen-a
# No vector for: pfizerpen-as
# No vector for: phenazine-35
# No vector for: phenetron
# No vector for: pheny-pas-tebamin
# No vector for: phenytek
# No vector for: phenytex
# No vector for: philith
# No vector for: phiso-scrub
# No vector for: phoslo
# No vector for: phoslyra
# No vector for: phosphotec
# No vector for: phosphotope
# No vector for: photrexa
# No vector for: phrenilin
# No vector for: pifeltro
# No vector for: pimtrea
# No vector for: pindac
# No vector for: piqray
# No vector for: pirmella 1/35
# No vector for: pirmella 7/7/7
# No vector for: pizensy
# No vector for: platinol-aq
# No vector for: plegine
# No vector for: plegridy
# No vector for: plenvu
# No vector for: pliaglis
# No vector for: polmon
# No vector for: polocaine-mpf
# No vector for: poly-pred
# No vector for: poly-rx
# No vector for: polycillin
# No vector for: polycillin-n
# No vector for: polycillin-prb
# No vector for: polymox
# No vector for: portalac
# No vector for: portia-21
# No vector for: portia-28
# No vector for: portrazza
# No vector for: povan
# No vector for: prabotulinumtoxina-xvfs
# No vector for: pramine
# No vector for: pramosone
# No vector for: prandimet
# No vector for: prandin
# No vector for: pre-sate
# No vector for: precef
# No vector for: pred-g
# No vector for: predair
# No vector for: predamide
# No vector for: prednicen-m
# No vector for: predsulfair
# No vector for: prefest
# No vector for: prefrin-a
# No vector for: prelone
# No vector for: premphase
# No vector for: premphase 14/14
# No vector for: prempro/premphase
# No vector for: prepopik
# No vector for: presamine
# No vector for: prestalia
# No vector for: prevalite
# No vector for: previfem
# No vector for: prevpac
# No vector for: prevymis
# No vector for: prexxartan
# No vector for: prezcobix
# No vector for: priftin
# No vector for: primacor
# No vector for: primsol
# No vector for: principen
# No vector for: principen '125'
# No vector for: principen '250'
# No vector for: principen '500'
# No vector for: prinzide
# No vector for: proamatine
# No vector for: probalan
# No vector for: probampacin
# No vector for: proben-c
# No vector for: procapan
# No vector for: procomp
# No vector for: proctocort
# No vector for: procysbi
# No vector for: profenal
# No vector for: proferdex
# No vector for: proglycem
# No vector for: proklar
# No vector for: prolensa
# No vector for: proloprim
# No vector for: promapar
# No vector for: promethacon
# No vector for: promethegan
# No vector for: pronestyl-sr
# No vector for: prostaphlin
# No vector for: protostat
# No vector for: provayblue
# No vector for: pseudo-12
# No vector for: psorcon
# No vector for: pulmolite
# No vector for: pur-wash
# No vector for: purixan
# No vector for: pyocidin
# No vector for: pytest
# No vector for: q-gesic
# No vector for: q-pam
# No vector for: qbrelis
# No vector for: qbrexza
# No vector for: qnasl
# No vector for: qoliana
# No vector for: qtern
# No vector for: qualaquin
# No vector for: quarzan
# No vector for: quasense
# No vector for: quibron-t/sr
# No vector for: quinact
# No vector for: quinalan
# No vector for: quinaretic
# No vector for: quinatime
# No vector for: quinora
# No vector for: quzyttir
# No vector for: radicava
# No vector for: raniclor
# No vector for: rapaflo
# No vector for: rapivab
# No vector for: raplon
# No vector for: rasuvo
# No vector for: rau-sed
# No vector for: rauserpin
# No vector for: rautensin
# No vector for: rauval
# No vector for: ravicti
# No vector for: ravulizumab-cwvz
# No vector for: raxar
# No vector for: rayaldee
# No vector for: rbc-scan
# No vector for: reblozyl
# No vector for: recarbrio
# No vector for: rectiv
# No vector for: redisol
# No vector for: reditrex
# No vector for: regonol
# No vector for: regroton
# No vector for: remsed
# No vector for: renese-r
# No vector for: renflexis
# No vector for: reno-30
# No vector for: reno-60
# No vector for: reno-dip
# No vector for: renocal-76
# No vector for: renoquid
# No vector for: renormax
# No vector for: renotec
# No vector for: renovue-65
# No vector for: renovue-dip
# No vector for: renvela
# No vector for: reprexain
# No vector for: resectisol
# No vector for: resporal
# No vector for: retet
# No vector for: retin-a-micro
# No vector for: revcovi
# No vector for: reversol
# No vector for: revonto
# No vector for: reyvow
# No vector for: rezipas
# No vector for: rezira
# No vector for: rhofade
# No vector for: rhopressa
# No vector for: ribasphere
# No vector for: rinvoq
# No vector for: riomet
# No vector for: risankizumab-rzaa
# No vector for: rituximab-abbs
# No vector for: rituximab-pvvr
# No vector for: robaxin-750
# No vector for: robaxisal
# No vector for: robengatope
# No vector for: robimycin
# No vector for: robitet
# No vector for: rocklatan
# No vector for: romosozumab-aqqg
# No vector for: roxicet
# No vector for: roxicet 5/500
# No vector for: roxilox
# No vector for: roxiprin
# No vector for: roxybond
# No vector for: rozlytrek
# No vector for: rubex
# No vector for: rubivite
# No vector for: ruby-fill
# No vector for: rufen
# No vector for: ruvite
# No vector for: ruxience
# No vector for: ruzurgi
# No vector for: ryanodex
# No vector for: rybelsus
# No vector for: rydapt
# No vector for: ryzodeg 70/30
# No vector for: ryzolt
# No vector for: s.a.s.-500
# No vector for: safyral
# No vector for: salonpas
# No vector for: saluron
# No vector for: salutensin
# No vector for: salutensin-demi
# No vector for: samsca
# No vector for: sandril
# No vector for: sansac
# No vector for: sarclisa
# No vector for: sarenin
# No vector for: sarisol
# No vector for: satric
# No vector for: scabene
# No vector for: scanlux-300
# No vector for: scanlux-370
# No vector for: sclerosol
# No vector for: secreflo
# No vector for: secretin-ferring
# No vector for: secuado
# No vector for: sedapap
# No vector for: seffin
# No vector for: segluromet
# No vector for: seizalam
# No vector for: selfemra
# No vector for: septi-soft
# No vector for: septocaine
# No vector for: ser-a-gen
# No vector for: ser-ap-es
# No vector for: sernivo
# No vector for: serpalan
# No vector for: serpanray
# No vector for: serpasil-apresoline
# No vector for: serpasil-esidrix #1
# No vector for: serpasil-esidrix #2
# No vector for: serpate
# No vector for: serpivite
# No vector for: servisone
# No vector for: sethotope
# No vector for: setlakin
# No vector for: seysara
# No vector for: sfrowasa
# No vector for: sildaflo
# No vector for: silenor
# No vector for: siliq
# No vector for: silphen
# No vector for: simbrinza
# No vector for: simethicone-cellulose
# No vector for: simpesse
# No vector for: sinuva
# No vector for: sitavig
# No vector for: sivextro
# No vector for: skelid
# No vector for: sklice
# No vector for: skyrizi
# No vector for: slynd
# No vector for: solage
# No vector for: solatene
# No vector for: soliqua 100/33
# No vector for: solodyn
# No vector for: solosec
# No vector for: soltamox
# No vector for: soluprep
# No vector for: somophyllin-df
# No vector for: somophyllin-t
# No vector for: sonazine
# No vector for: sonorx
# No vector for: sorilux
# No vector for: sorine
# No vector for: sosol
# No vector for: sotret
# No vector for: sotylize
# No vector for: soxazole
# No vector for: soy-dome
# No vector for: spectamine
# No vector for: spectazole
# No vector for: spectrobid
# No vector for: spravato
# No vector for: sprintec
# No vector for: spritam
# No vector for: sprx-105
# No vector for: sprx-3
# No vector for: stanozide
# No vector for: staticin
# No vector for: statobex
# No vector for: statobex-g
# No vector for: statrol
# No vector for: stavzor
# No vector for: staxyn
# No vector for: steglatro
# No vector for: steglujan
# No vector for: steri-stat
# No vector for: steritalc
# No vector for: stie-cort
# No vector for: stilbetin
# No vector for: strensiq
# No vector for: sublocade
# No vector for: subsys
# No vector for: suclear
# No vector for: sucostrin
# No vector for: sucraid
# No vector for: sular
# No vector for: sulf-10
# No vector for: sulf-15
# No vector for: sulfa-triple #2
# No vector for: sulfabid
# No vector for: sulfacel-15
# No vector for: sulfair-15
# No vector for: sulfalar
# No vector for: sulfaloid
# No vector for: sulfamethoprim
# No vector for: sulfamethoprim-ds
# No vector for: sulfatrim-ds
# No vector for: sulfatrim-ss
# No vector for: sulfose
# No vector for: sulmeprim
# No vector for: sulphrin
# No vector for: sulsoxin
# No vector for: sulster
# No vector for: sulten-10
# No vector for: sultrin
# No vector for: sunosi
# No vector for: supprelin
# No vector for: suprenza
# No vector for: sustaire
# No vector for: sustol
# No vector for: syeda
# No vector for: sylevia
# No vector for: symadine
# No vector for: symdeko
# No vector for: symfi
# No vector for: symjepi
# No vector for: sympazan
# No vector for: symproic
# No vector for: symtuza
# No vector for: synacort
# No vector for: synalar-hp
# No vector for: synalgos-dc
# No vector for: synalgos-dc-a
# No vector for: syndros
# No vector for: synjardy
# No vector for: synophylate
# No vector for: t-phyl
# No vector for: tab-profen
# No vector for: tacaryl
# No vector for: tagraxofusp-erzs
# No vector for: takhzyro
# No vector for: talacen
# No vector for: talbutal
# No vector for: talicia
# No vector for: talzenna
# No vector for: targiniq
# No vector for: tavalisse
# No vector for: tavist-1
# No vector for: taytulla
# No vector for: tazicef
# No vector for: tazidime
# No vector for: tazverik
# No vector for: technecoll
# No vector for: technelite
# No vector for: technivie
# No vector for: teczem
# No vector for: teebacin
# No vector for: tegopen
# No vector for: tegsedi
# No vector for: tekamlo
# No vector for: teldrin
# No vector for: temaril
# No vector for: temaz
# No vector for: temixys
# No vector for: ten-k
# No vector for: tenathan
# No vector for: tepadina
# No vector for: tepanil
# No vector for: tepanil ten-tab
# No vector for: tepezza
# No vector for: teprotumumab-trbw
# No vector for: terfonyl
# No vector for: terramycin-polymyxin
# No vector for: testred
# No vector for: tesuloid
# No vector for: tetrachel
# No vector for: tetramed
# No vector for: tetrex
# No vector for: texacort
# No vector for: thalitone
# No vector for: theelin
# No vector for: theochron
# No vector for: theoclear l.a.-130
# No vector for: theoclear l.a.-260
# No vector for: theoclear-100
# No vector for: theoclear-200
# No vector for: theoclear-80
# No vector for: theolixir
# No vector for: theophyl
# No vector for: theophyl-225
# No vector for: theophyl-sr
# No vector for: theophylline-sr
# No vector for: thermazene
# No vector for: theroxidil
# No vector for: thioplex
# No vector for: thypinone
# No vector for: thyro-block
# No vector for: thyro-tabs
# No vector for: thyrolar-0.25
# No vector for: thyrolar-0.5
# No vector for: thyrolar-1
# No vector for: thyrolar-2
# No vector for: thyrolar-3
# No vector for: thyrolar-5
# No vector for: thyrosafe
# No vector for: thyroshield
# No vector for: tiamate
# No vector for: tibsovo
# No vector for: tildrakizumab-asmn
# No vector for: tindamax
# No vector for: tirosint
# No vector for: tirosint-sol
# No vector for: tissueblue
# No vector for: tivorbex
# No vector for: tobrasone
# No vector for: tofranil-pm
# No vector for: tolak
# No vector for: tolsura
# No vector for: tonocard
# No vector for: topicycline
# No vector for: toposar
# No vector for: toprol-xl
# No vector for: tosymra
# No vector for: totacillin
# No vector for: totacillin-n
# No vector for: tpoxx
# No vector for: tranmep
# No vector for: trastuzumab-anns
# No vector for: trastuzumab-dkst
# No vector for: trastuzumab-dttb
# No vector for: trastuzumab-pkrb
# No vector for: trastuzumab-qyyp
# No vector for: trazimera
# No vector for: tremfya
# No vector for: trexall
# No vector for: trezix
# No vector for: tri-estarylla
# No vector for: tri-linyah
# No vector for: tri-lo-estarylla
# No vector for: tri-lo-linyah
# No vector for: tri-lo-mili
# No vector for: tri-mili
# No vector for: tri-previfem
# No vector for: tri-sprintec
# No vector for: triacet
# No vector for: triacin-c
# No vector for: triacort
# No vector for: trialodine
# No vector for: triaminic-12
# No vector for: triaprin
# No vector for: triatex
# No vector for: tribenzor
# No vector for: trichlorex
# No vector for: trichlormas
# No vector for: triclos
# No vector for: tridesilon
# No vector for: tridil
# No vector for: trifarotene
# No vector for: triglide
# No vector for: trikafta
# No vector for: trilitron
# No vector for: trilyte
# No vector for: trimeth/sulfa
# No vector for: trimox
# No vector for: trimpex
# No vector for: trinalin
# No vector for: trintellix
# No vector for: triphasil-21
# No vector for: triphed
# No vector for: trivaris
# No vector for: trivora-21
# No vector for: trivora-28
# No vector for: trogarzo
# No vector for: tropicacyl
# No vector for: trulance
# No vector for: truphylline
# No vector for: trymex
# No vector for: trysul
# No vector for: turalio
# No vector for: turgex
# No vector for: tussicaps
# No vector for: tussigon
# No vector for: tussionex pennkinetic
# No vector for: twirla
# No vector for: twynsta
# No vector for: tybost
# No vector for: tycolet
# No vector for: tydemy
# No vector for: tylox
# No vector for: tylox-325
# No vector for: tymlos
# No vector for: tymtran
# No vector for: tyzeka
# No vector for: tz-3
# No vector for: u-cort
# No vector for: u-gencin
# No vector for: ubrelvy
# No vector for: ucephan
# No vector for: udenyca
# No vector for: ulesfia
# No vector for: ultacan
# No vector for: ultomiris
# No vector for: ultracef
# No vector for: ultragris-165
# No vector for: ultragris-330
# No vector for: ultravate
# No vector for: unipen
# No vector for: unipres
# No vector for: uniretic
# No vector for: unisom
# No vector for: unitensen
# No vector for: unithroid
# No vector for: univasc
# No vector for: ureaphil
# No vector for: urese
# No vector for: urispas
# No vector for: urobak
# No vector for: utibron
# No vector for: uticort
# No vector for: utimox
# No vector for: uvadex
# No vector for: vabomere
# No vector for: vagilia
# No vector for: vagistat-1
# No vector for: valchlor
# No vector for: valnac
# No vector for: valrelease
# No vector for: valtoco
# No vector for: valturna
# No vector for: vancenase
# No vector for: vancor
# No vector for: vandazole
# No vector for: vanobid
# No vector for: vanos
# No vector for: vantin
# No vector for: vapo-iso
# No vector for: vaseretic
# No vector for: vasocon
# No vector for: vasostrict
# No vector for: vazalore
# No vector for: vazculep
# No vector for: veetids
# No vector for: veetids '125'
# No vector for: veetids '250'
# No vector for: veetids '500'
# No vector for: veinamine 8%
# No vector for: velivet
# No vector for: velphoro
# No vector for: veltane
# No vector for: veltassa
# No vector for: veltin
# No vector for: vemlidy
# No vector for: ventaire
# No vector for: verard
# No vector for: verdeso
# No vector for: vermidol
# No vector for: versacloz
# No vector for: versapen-k
# No vector for: vertavis
# No vector for: verzenio
# No vector for: vestronidase alfa-vjbk
# No vector for: vexol
# No vector for: vi-dom-a
# No vector for: vi-twel
# No vector for: vibisone
# No vector for: vibra-tabs
# No vector for: vicoprin
# No vector for: vienva
# No vector for: vigadrone
# No vector for: vincrex
# No vector for: viokace
# No vector for: viorele
# No vector for: virilon
# No vector for: viskazide
# No vector for: vitaped
# No vector for: vitekta
# No vector for: vitrakvi
# No vector for: vituz
# No vector for: vivelle-dot
# No vector for: vivlodex
# No vector for: vizimpro
# No vector for: vogelxo
# No vector for: volnea
# No vector for: voltaren-xr
# No vector for: vosevi
# No vector for: voxelotor
# No vector for: vraylar
# No vector for: vumerity
# No vector for: vusion
# No vector for: vyepti
# No vector for: vyfemla
# No vector for: vyleesi
# No vector for: vyndamax
# No vector for: vyxeos
# No vector for: vyzulta
# No vector for: wakix
# No vector for: wampocap
# No vector for: wellcovorin
# No vector for: westadone
# No vector for: westcort
# No vector for: wigraine
# No vector for: wigrettes
# No vector for: wilpo
# No vector for: wixela inhub
# No vector for: wolfina
# No vector for: wygesic
# No vector for: wymox
# No vector for: x-trozine
# No vector for: x-trozine l.a.
# No vector for: xatmep
# No vector for: xcopri
# No vector for: xelpros
# No vector for: xenazine
# No vector for: xeneisol
# No vector for: xenleta
# No vector for: xepi
# No vector for: xerava
# No vector for: xermelo
# No vector for: xhance
# No vector for: xiidra
# No vector for: ximino
# No vector for: xofluza
# No vector for: xolegel
# No vector for: xospata
# No vector for: xpovio
# No vector for: xtoro
# No vector for: xtrelus
# No vector for: xulane
# No vector for: xuriden
# No vector for: xylo-pfan
# No vector for: xyosted
# No vector for: xyrosa
# No vector for: yaela
# No vector for: yonsa
# No vector for: yosprala
# No vector for: yupelri
# No vector for: yutiq
# No vector for: zagam
# No vector for: zanubrutinib
# No vector for: zaroxolyn
# No vector for: zaxopam
# No vector for: zebeta
# No vector for: zefazone
# No vector for: zejula
# No vector for: zelapar
# No vector for: zembrace symtouch
# No vector for: zemdri
# No vector for: zemuron
# No vector for: zenatane
# No vector for: zenavod
# No vector for: zeposia
# No vector for: zerbaxa
# No vector for: zerviate
# No vector for: zestoretic
# No vector for: zetonna
# No vector for: ziac
# No vector for: ziba-rx
# No vector for: zide
# No vector for: ziextenzo
# No vector for: zilretta
# No vector for: zingo
# No vector for: zioptan
# No vector for: zipan-25
# No vector for: zipan-50
# No vector for: zipsor
# No vector for: zirabev
# No vector for: zirgan
# No vector for: zomig-zmt
# No vector for: zonalon
# No vector for: zorbtive
# No vector for: zortress
# No vector for: zorvolex
# No vector for: zovia 1/35e-21
# No vector for: zovia 1/35e-28
# No vector for: zovia 1/50e-21
# No vector for: zovia 1/50e-28
# No vector for: ztlido
# No vector for: zulresso
# No vector for: zumandimine
# No vector for: zuplenz
# No vector for: zuragard
# No vector for: zutripro
# No vector for: zyclara
# No vector for: zydone
# No vector for: zyfrel
# No vector for: zymaxid
# No vector for: zypitamag

# %%
# now get the sars treatment endpoint vector
metf_v = wv['metformin'] / np.linalg.norm(wv['metformin'])
diab_v = wv['diabetes'] / np.linalg.norm(wv['diabetes'])
sars_v = wv['sars'] / np.linalg.norm(wv['sars'])
treat_sars_vec = metf_v - diab_v + sars_v
treat_sars_vec = treat_sars_vec / np.linalg.norm(treat_sars_vec)

# %%
# and rank our drug vectors by their distance from the sars treatment vector
# the drug vectors are currently stored as tuples with the original name
dvs = np.array([dt[1] for dt in drug_vectors])
drug2treat_sims = wv.cosine_similarities(treat_sars_vec, dvs)
# put those similarities into tuples with the drug names now
drug_sim_tuples = list()
for i,dt in enumerate(drug_vectors):
    dn = dt[0]
    sim = drug2treat_sims[i]
    drug_sim_tuples.append((dn,sim))
# and sort by similarity descending
ranked_results = sorted(drug_sim_tuples, key=lambda x: x[1], reverse=True)
ranked_results_str = [str(tup) for tup in ranked_results]
print('\n'.join(ranked_results_str[:100]))
# Out:
# ('gilteritinib fumarate', 0.5596476)
# ('peramivir', 0.55696976)
# ('zanamivir', 0.5469999)
# ('erdafitinib', 0.528765)
# ('atovaquone and proguanil hydrochloride', 0.5266413)
# ('rimantadine hydrochloride', 0.52499855)
# ('delavirdine mesylate', 0.5242566)
# ('atazanavir sulfate and ritonavir', 0.5215566)
# ('cobimetinib fumarate', 0.520225)
# ('niclosamide', 0.51958627)
# ('lopinavir and ritonavir', 0.51907957)
# ('temsirolimus', 0.51461643)
# ('rilpivirine hydrochloride', 0.51084423)
# ('alectinib hydrochloride', 0.5094976)
# ('lefamulin acetate', 0.5077356)
# ('perphenazine and amitriptyline hydrochloride', 0.5071963)
# ('alogliptin and metformin hydrochloride', 0.506837)
# ('tamiflu', 0.50654095)
# ('selinexor', 0.5053856)
# ('amprenavir', 0.50434387)
# ('ibuprofen and diphenhydramine citrate', 0.5035539)
# ('olanzapine and fluoxetine hydrochloride', 0.50291455)
# ('probenecid and colchicine', 0.50227225)
# ('erlotinib hydrochloride', 0.5016403)
# ('bicalutamide', 0.5016144)
# ('alomide', 0.50147206)
# ('amantadine hydrochloride', 0.5013115)
# ('azelastine hydrochloride and fluticasone propionate', 0.5008869)
# ('revefenacin', 0.5004103)
# ('imipramine pamoate', 0.5000387)
# ('doravirine', 0.5000229)
# ('rosiglitazone maleate and metformin hydrochloride', 0.4987201)
# ('nefazodone hydrochloride', 0.49831775)
# ('mefloquine hydrochloride', 0.49804157)
# ('abacavir sulfate and lamivudine', 0.49790424)
# ('carisoprodol compound', 0.49745345)
# ('triprolidine and pseudoephedrine hydrochlorides w/ codeine', 0.4970367)
# ('soma compound w/ codeine', 0.4970075)
# ('chloroquine hydrochloride', 0.49607554)
# ('saquinavir mesylate', 0.49556127)
# ('linagliptin and metformin hydrochloride', 0.49545383)
# ('nilutamide', 0.4947096)
# ('memantine hydrochloride and donepezil hydrochloride', 0.49466503)
# ('donepezil hydrochloride and memantine hydrochloride', 0.494665)
# ('nelfinavir mesylate', 0.49460104)
# ('ceritinib', 0.49452412)
# ('virazole', 0.49377725)
# ('vorinostat', 0.493377)
# ('triprolidine and pseudoephedrine hydrochlorides', 0.49315724)
# ('fulvestrant', 0.49243176)
# ('gefitinib', 0.49215955)
# ('oseltamivir phosphate', 0.49202573)
# ('ibuprofen and diphenhydramine hydrochloride', 0.49155578)
# ('formoterol fumarate', 0.4914922)
# ('bedaquiline fumarate', 0.49117547)
# ('efavirenz, lamivudine and tenofovir disoproxil fumarate', 0.4911253)
# ('lamivudine and tenofovir disoproxil fumarate', 0.4911253)
# ('stiripentol', 0.49097416)
# ('propoxyphene hydrochloride and acetaminophen', 0.49053428)
# ('desvenlafaxine fumarate', 0.48947012)
# ('dolutegravir, lamivudine, and tenofovir disoproxil fumarate', 0.48873723)
# ('efavirenz, emtricitabine, and tenofovir disoproxil fumarate', 0.48873723)
# ('efavirenz, lamivudine, and tenofovir disoproxil fumarate', 0.48873723)
# ('ribociclib succinate', 0.48872223)
# ('repaglinide and metformin hydrochloride', 0.48846084)
# ('ponatinib hydrochloride', 0.48823822)
# ('alpelisib', 0.48772085)
# ('alosetron hydrochloride', 0.48767075)
# ('quetiapine fumarate', 0.48739555)
# ('emtricitabine and tenofovir disoproxil fumarate', 0.48727348)
# ('belinostat', 0.4870355)
# ('metformin hydrochloride', 0.48669204)
# ('olaparib', 0.48657638)
# ('loratadine and pseudoephedrine sulfate', 0.48644036)
# ('upadacitinib', 0.48629883)
# ('fedratinib hydrochloride', 0.48607233)
# ('advil dual action with acetaminophen', 0.4858105)
# ('acetaminophen and pentazocine hydrochloride', 0.48560187)
# ('ixazomib citrate', 0.48537463)
# ('dextromethorphan hydrobromide and quinidine sulfate', 0.48524997)
# ('darolutamide', 0.48514158)
# ('glyburide and metformin hydrochloride', 0.48509055)
# ('clemastine fumarate', 0.4850625)
# ('roflumilast', 0.48498142)
# ('amodiaquine hydrochloride', 0.48477876)
# ('lamivudine and stavudine', 0.4842411)
# ('hydrocodone polistirex and chlorpheniramine polistirex', 0.48414958)
# ('lapatinib ditosylate', 0.48402143)
# ('fesoterodine fumarate', 0.48378024)
# ('daclatasvir dihydrochloride', 0.48337704)
# ('promethazine with codeine', 0.483318)
# ('pazopanib hydrochloride', 0.48329502)
# ('aminophyllin', 0.48286176)
# ('sulfamethoxazole and trimethoprim and phenazopyridine hydrochloride', 0.48280194)
# ('ketotifen fumarate', 0.48226255)
# ('pioglitazone hydrochloride and metformin hydrochloride', 0.4822104)
# ('norethindrone and ethinyl estradiol and ferrous fumarate', 0.48215058)
# ('celecoxib', 0.4821071)
# ('chlordiazepoxide and amitriptyline hydrochloride', 0.48201525)
# ('abemaciclib', 0.4819321)

# %%
for i,dst in enumerate(drug_sim_tuples):
    if 'prazosin' in dst[0]:
        print((i, dst[0], dst[1]))
# Out:
# (4775, 'prazosin hydrochloride', 0.41114467)

# %%
# prep the top 100 for manual review
for i,rr in enumerate(ranked_results[:100]):
    print('{0}. {1} \\[{2:.3f}\\]'.format(i+1, rr[0], rr[1]))
# Out:
# 1. gilteritinib fumarate \[0.560\]
# 2. peramivir \[0.557\]
# 3. zanamivir \[0.547\]
# 4. erdafitinib \[0.529\]
# 5. atovaquone and proguanil hydrochloride \[0.527\]
# 6. rimantadine hydrochloride \[0.525\]
# 7. delavirdine mesylate \[0.524\]
# 8. atazanavir sulfate and ritonavir \[0.522\]
# 9. cobimetinib fumarate \[0.520\]
# 10. niclosamide \[0.520\]
# 11. lopinavir and ritonavir \[0.519\]
# 12. temsirolimus \[0.515\]
# 13. rilpivirine hydrochloride \[0.511\]
# 14. alectinib hydrochloride \[0.509\]
# 15. lefamulin acetate \[0.508\]
# 16. perphenazine and amitriptyline hydrochloride \[0.507\]
# 17. alogliptin and metformin hydrochloride \[0.507\]
# 18. tamiflu \[0.507\]
# 19. selinexor \[0.505\]
# 20. amprenavir \[0.504\]
# 21. ibuprofen and diphenhydramine citrate \[0.504\]
# 22. olanzapine and fluoxetine hydrochloride \[0.503\]
# 23. probenecid and colchicine \[0.502\]
# 24. erlotinib hydrochloride \[0.502\]
# 25. bicalutamide \[0.502\]
# 26. alomide \[0.501\]
# 27. amantadine hydrochloride \[0.501\]
# 28. azelastine hydrochloride and fluticasone propionate \[0.501\]
# 29. revefenacin \[0.500\]
# 30. imipramine pamoate \[0.500\]
# 31. doravirine \[0.500\]
# 32. rosiglitazone maleate and metformin hydrochloride \[0.499\]
# 33. nefazodone hydrochloride \[0.498\]
# 34. mefloquine hydrochloride \[0.498\]
# 35. abacavir sulfate and lamivudine \[0.498\]
# 36. carisoprodol compound \[0.497\]
# 37. triprolidine and pseudoephedrine hydrochlorides w/ codeine \[0.497\]
# 38. soma compound w/ codeine \[0.497\]
# 39. chloroquine hydrochloride \[0.496\]
# 40. saquinavir mesylate \[0.496\]
# 41. linagliptin and metformin hydrochloride \[0.495\]
# 42. nilutamide \[0.495\]
# 43. memantine hydrochloride and donepezil hydrochloride \[0.495\]
# 44. donepezil hydrochloride and memantine hydrochloride \[0.495\]
# 45. nelfinavir mesylate \[0.495\]
# 46. ceritinib \[0.495\]
# 47. virazole \[0.494\]
# 48. vorinostat \[0.493\]
# 49. triprolidine and pseudoephedrine hydrochlorides \[0.493\]
# 50. fulvestrant \[0.492\]
# 51. gefitinib \[0.492\]
# 52. oseltamivir phosphate \[0.492\]
# 53. ibuprofen and diphenhydramine hydrochloride \[0.492\]
# 54. formoterol fumarate \[0.491\]
# 55. bedaquiline fumarate \[0.491\]
# 56. efavirenz, lamivudine and tenofovir disoproxil fumarate \[0.491\]
# 57. lamivudine and tenofovir disoproxil fumarate \[0.491\]
# 58. stiripentol \[0.491\]
# 59. propoxyphene hydrochloride and acetaminophen \[0.491\]
# 60. desvenlafaxine fumarate \[0.489\]
# 61. dolutegravir, lamivudine, and tenofovir disoproxil fumarate \[0.489\]
# 62. efavirenz, emtricitabine, and tenofovir disoproxil fumarate \[0.489\]
# 63. efavirenz, lamivudine, and tenofovir disoproxil fumarate \[0.489\]
# 64. ribociclib succinate \[0.489\]
# 65. repaglinide and metformin hydrochloride \[0.488\]
# 66. ponatinib hydrochloride \[0.488\]
# 67. alpelisib \[0.488\]
# 68. alosetron hydrochloride \[0.488\]
# 69. quetiapine fumarate \[0.487\]
# 70. emtricitabine and tenofovir disoproxil fumarate \[0.487\]
# 71. belinostat \[0.487\]
# 72. metformin hydrochloride \[0.487\]
# 73. olaparib \[0.487\]
# 74. loratadine and pseudoephedrine sulfate \[0.486\]
# 75. upadacitinib \[0.486\]
# 76. fedratinib hydrochloride \[0.486\]
# 77. advil dual action with acetaminophen \[0.486\]
# 78. acetaminophen and pentazocine hydrochloride \[0.486\]
# 79. ixazomib citrate \[0.485\]
# 80. dextromethorphan hydrobromide and quinidine sulfate \[0.485\]
# 81. darolutamide \[0.485\]
# 82. glyburide and metformin hydrochloride \[0.485\]
# 83. clemastine fumarate \[0.485\]
# 84. roflumilast \[0.485\]
# 85. amodiaquine hydrochloride \[0.485\]
# 86. lamivudine and stavudine \[0.484\]
# 87. hydrocodone polistirex and chlorpheniramine polistirex \[0.484\]
# 88. lapatinib ditosylate \[0.484\]
# 89. fesoterodine fumarate \[0.484\]
# 90. daclatasvir dihydrochloride \[0.483\]
# 91. promethazine with codeine \[0.483\]
# 92. pazopanib hydrochloride \[0.483\]
# 93. aminophyllin \[0.483\]
# 94. sulfamethoxazole and trimethoprim and phenazopyridine hydrochloride \[0.483\]
# 95. ketotifen fumarate \[0.482\]
# 96. pioglitazone hydrochloride and metformin hydrochloride \[0.482\]
# 97. norethindrone and ethinyl estradiol and ferrous fumarate \[0.482\]
# 98. celecoxib \[0.482\]
# 99. chlordiazepoxide and amitriptyline hydrochloride \[0.482\]
# 100. abemaciclib \[0.482\]

# %%
for i,dst in enumerate(drug_sim_tuples):
    if 'baricitinib' in dst[0]:
        print((i, dst[0], dst[1]))
# Out:
# (625, 'baricitinib', 0.40153417)

# %%
len(ranked_results)
# Out:
# 6506

# %%
with open('sars.metformin_diabetes.approved.full.txt', 'w') as outfile:
    outfile.write('hit\tsimilarity\n')
    for hit,sim in ranked_results:
        outfile.write('{0}\t{1}\n'.format(hit, sim))
